# %% [markdown]
# <a href="https://colab.research.google.com/github/meburns2011/School-Details-SQLAlchemy-Database/blob/main/SQLAlchemy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
school_df = pd.read_csv('/content/School_Details.csv')
# make sure it loaded correctly
school_df.head(2)
# Out:
#   DistrictName EstablishmentCode  \
# 0         East             S0169
# 1         East             S0099
#
#                                    EstablishmentName   BRCName  \
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)  Duga Brc
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL  Duga Brc
#
#                                              CRCName SchoolLevel  \
# 0  Central Pendam Government Senior Secondary School          PS
# 1  Central Pendam Government Senior Secondary School         SSS
#
#   ManagementName LocalityHabitation SubdivisionName ConstituencyName  ...  \
# 0    State Govt.             BUDANG         Gangtok          Rhenock  ...
# 1    State Govt.     CENTRAL PENDAM         Gangtok      West Pandam  ...
#
#   EstablishedDate DistrictHQDistance (in Km) CRCDistance (in Km)  \
# 0           28126                       58.0                 8.0
# 1           15342                       50.0                 0.0
#
# ...

# %%
#create sqlite engine for a database called schools
engine=create_engine('sqlite:///schools.db', echo=True)
#create connection to engine
conn=engine.connect()

# %%
sqlite_table='school_details'
school_df.to_sql(sqlite_table, conn,if_exists='fail')
# Out:
# 2022-08-25 18:21:43,329 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("school_details")
# INFO:sqlalchemy.engine.Engine:PRAGMA main.table_info("school_details")
# 2022-08-25 18:21:43,336 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2022-08-25 18:21:43,339 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("school_details")
# INFO:sqlalchemy.engine.Engine:PRAGMA temp.table_info("school_details")
# 2022-08-25 18:21:43,343 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
# 2022-08-25 18:21:43,355 INFO sqlalchemy.engine.Engine
# CREATE TABLE school_details (
# 	"index" BIGINT,
# 	"DistrictName" TEXT,
# 	"EstablishmentCode" TEXT,
# 	"EstablishmentName" TEXT,
# 	"BRCName" TEXT,
# 	"CRCName" TEXT,
# 	"SchoolLevel" TEXT,
# 	"ManagementName" TEXT,
# 	"LocalityHabitation" TEXT,
# 	"SubdivisionName" TEXT,
# 	"ConstituencyName" TEXT,
# 	"RevenueBlockName" TEXT,
# 	"CivicBodyName" TEXT,
# ...

# %%
sql="""
SELECT DistrictName
FROM school_details
Limit3;
"""

pd.read_sql_query(sql, engine)
# Out:
# 2022-08-25 18:21:48,250 INFO sqlalchemy.engine.Engine
# SELECT DistrictName
# FROM school_details
# Limit3;
# INFO:sqlalchemy.engine.Engine:
# SELECT DistrictName
# FROM school_details
# Limit3;
# 2022-08-25 18:21:48,258 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#      DistrictName
# 0            East
# 1            East
# 2            East
# 3            East
# 4            East
# ...           ...
# 1244         West
# 1245         West
# 1246         West
# 1247         West
# 1248         West
#
# [1249 rows x 1 columns]

# %% [markdown]
# ##SELECT and FROM

# %%
sql = """SELECT SchoolLevel, ManagementName
 FROM school_details; 
 """
# Read the sql query into pandas to view the results
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-14 16:02:15,254 INFO sqlalchemy.engine.Engine SELECT SchoolLevel, ManagementName
#  FROM school_details;
# INFO:sqlalchemy.engine.Engine:SELECT SchoolLevel, ManagementName
#  FROM school_details;
# 2022-08-14 16:02:15,264 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#      SchoolLevel     ManagementName
# 0             PS        State Govt.
# 1            SSS        State Govt.
# 2             SS  Private (Unaided)
# 3            JHS        State Govt.
# 4             SS        State Govt.
# ...          ...                ...
# 1244          PS        State Govt.
# 1245          PS        State Govt.
# 1246          PS  Private (Unaided)
# 1247          PS        State Govt.
# 1248          PS        State Govt.
#
# [1249 rows x 2 columns]

# %%
sql = """SELECT * 
FROM school_details;
"""
# execute the sql query
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-14 16:02:17,206 INFO sqlalchemy.engine.Engine SELECT *
# FROM school_details;
# INFO:sqlalchemy.engine.Engine:SELECT *
# FROM school_details;
# 2022-08-14 16:02:17,215 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#       index DistrictName EstablishmentCode  \
# 0         0         East             S0169
# 1         1         East             S0099
# 2         2         East             S0848
# 3         3         East             S0190
# 4         4         East             S0111
# ...     ...          ...               ...
# 1244   1244         West             S0336
# 1245   1245         West             S0591
# 1246   1246         West             S1045
# 1247   1247         West             S0340
# 1248   1248         West             S0542
#
#                                       EstablishmentName     BRCName  \
# 0                  BUDANG GOVERNMENT PRIMARY SCHOOL (E)    Duga Brc
# ...

# %%
sql=""" SELECT WardName, PostOfficeName
FROM school_details;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-09 18:56:17,355 INFO sqlalchemy.engine.Engine  SELECT WardName, PostOfficeName
# FROM school_details;
# INFO:sqlalchemy.engine.Engine: SELECT WardName, PostOfficeName
# FROM school_details;
# 2022-08-09 18:56:17,367 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                         WardName PostOfficeName
# 0                                         Sajong   Upper Pendam
# 1                                     Karmithang   Upper Pendam
# 2                                         Burung   Upper Pendam
# 3                                    Cheuribotey           Duga
# 4                                           Duga           Duga
# ...                                          ...            ...
# 1244                                  Mangsabong         Yuksom
# 1245                                      Yoksam         Yuksom
# 1246  Tashiding Tashiding Chogyal Lhakhang Gumpa         Yuksom
# ...

# %%
sql="""SELECT `CRCDistance (in km)`
FROM school_details;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-10 00:18:38,808 INFO sqlalchemy.engine.Engine SELECT `CRCDistance (in km)`
# FROM school_details;
# INFO:sqlalchemy.engine.Engine:SELECT `CRCDistance (in km)`
# FROM school_details;
# 2022-08-10 00:18:38,812 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#       CRCDistance (in Km)
# 0                     8.0
# 1                     0.0
# 2                     1.5
# 3                     6.0
# 4                     0.0
# ...                   ...
# 1244                  4.0
# 1245                  2.0
# 1246                  0.0
# 1247                  3.0
# 1248                  7.0
#
# [1249 rows x 1 columns]

# %% [markdown]
# #Where

# %%
sql="""SELECT EstablishmentName, CRCName, `CRCDistance (in Km)`
FROM school_details
WHERE `CRCDistance (in Km)` > 5;
"""

pd.read_sql_query(sql, engine)
# Out:
# 2022-08-10 00:25:32,812 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, CRCName, `CRCDistance (in Km)`
# FROM school_details
# WHERE `CRCDistance (in Km)` > 5;
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName, CRCName, `CRCDistance (in Km)`
# FROM school_details
# WHERE `CRCDistance (in Km)` > 5;
# 2022-08-10 00:25:32,823 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                  EstablishmentName  \
# 0             BUDANG GOVERNMENT PRIMARY SCHOOL (E)
# 1    CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)
# 2              NEW GARDEN BOARDING SCHOOL (SAJONG)
# 3               PACHAK GOVERNMENT SECONDARY SCHOOL
# 4                 PADMA KUMARI PUBLIC SCHOOL, DUGA
# ..                                             ...
# 352       NAMBUMANGTHANG GOVERNMENT PRIMARY SCHOOL
# 353             NERDHANG GOVERNMENT PRIMARY SCHOOL
# 354               RANGIT GOVERNMENT PRIMARY SCHOOL
# ...

# %%
sql= """SELECT EstablishmentName 
FROM school_details
WHERE SchoolLevel='PS';
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-10 00:27:12,757 INFO sqlalchemy.engine.Engine SELECT EstablishmentName
# FROM school_details
# WHERE SchoolLevel='PS';
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName
# FROM school_details
# WHERE SchoolLevel='PS';
# 2022-08-10 00:27:12,774 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                              EstablishmentName
# 0         BUDANG GOVERNMENT PRIMARY SCHOOL (E)
# 1             EASWARAMMA SAI GURUKOOL ACCADEMY
# 2          ETERNAL ENGLISH SCHOOL, WEST PENDAM
# 3         KHANI GOAN GOVERNMENT PRIMARY SCHOOL
# 4          NEW GARDEN BOARDING SCHOOL (SAJONG)
# ..                                         ...
# 630       MANGSABONG GOVERNMENT PRIMARY SCHOOL
# 631  MANGTABONG GOVERNMENT PRIMARY SCHOOL(SSA)
# 632      NEW HORIZON ACADEMY, LASSO(TASHIDING)
# 633    TINGTING GAON GOVERNMENT PRIMARY SCHOOL
# 634            TSONG GOVERNMENT PRIMARY SCHOOL
#
# [635 rows x 1 columns]

# %% [markdown]
# ##Wildcards % and Like

# %%
#SELECT column
#FROM table
#WHERE column LIKE 'a%'; (starts with letter a)

# %%
#SELECT column
#FROM table
#WHERE column LIKE '%a'; (ends with letter a)

# %%
#SELECT column
#FROM table
#WHERE column LIKE 'a%a'; (beginds and ends with letter a)

# %%
sql="""SELECT EstablishmentName, PostOfficeName
FROM school_details
WHERE EstablishmentName LIKE 'New%'
"""

pd.read_sql_query(sql, engine)
# Out:
# 2022-08-10 01:02:09,338 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, PostOfficeName
# FROM school_details
# WHERE EstablishmentName LIKE 'New%'
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName, PostOfficeName
# FROM school_details
# WHERE EstablishmentName LIKE 'New%'
# 2022-08-10 01:02:09,343 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                             EstablishmentName PostOfficeName
# 0         NEW GARDEN BOARDING SCHOOL (SAJONG)   Upper Pendam
# 1                         NEW HORIZON ACADEMY         Rongpo
# 2                NEW VISION ACADEMY, MAJHITAR       Majhitar
# 3           NEW VISION ACADEMY, CHOTA SINGTAM  Assam Lingzey
# 4         NEW GARDEN BOARDING SCHOOL, SINGTAM        Singtam
# 5                 NEW BUDS ACADEMY, JORETHANG     Naya Bazar
# 6              NEW LIGHT ACADEMY, ASSANGTHANG    Assangthang
# 7                    NEW LIGHT ACADEMY NAMCHI         Namchi
# ...

# %%
sql=""" SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE '%academy%'
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-10 01:03:30,776 INFO sqlalchemy.engine.Engine  SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE '%academy%'
# INFO:sqlalchemy.engine.Engine: SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE '%academy%'
# 2022-08-10 01:03:30,792 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                              EstablishmentName
# 0        CENTRAL POINT ACADEMY, CENTRAL PENDAM
# 1                        SUNRISE ACADEMY, DUGA
# 2                          NEW HORIZON ACADEMY
# 3                 NEW VISION ACADEMY, MAJHITAR
# 4            DE. NOBILE ACADEMY, ASSAM LINGZEY
# ..                                         ...
# 210       HIMALAYAN RADIANT ACADEMY, TASHIDING
# 211                  MARIGOLD ACADEMY, GANGYAP
# 212  MARIGOLD ACADEMY, POKHARI DARA, TASHIDING
# 213                LIFE VISION ACADEMY, YUKSAM
# 214      NEW HORIZON ACADEMY, LASSO(TASHIDING)
#
# [215 rows x 1 columns]

# %% [markdown]
# #Advanced Where

# %%
#Same column
sql="""SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%';
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-14 16:02:31,660 INFO sqlalchemy.engine.Engine SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%';
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%';
# 2022-08-14 16:02:31,677 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                             EstablishmentName
# 0                         NEW HORIZON ACADEMY
# 1                NEW VISION ACADEMY, MAJHITAR
# 2           NEW VISION ACADEMY, CHOTA SINGTAM
# 3                 NEW BUDS ACADEMY, JORETHANG
# 4              NEW LIGHT ACADEMY, ASSANGTHANG
# 5                    NEW LIGHT ACADEMY NAMCHI
# 6                 NEW STEPS ACADEMY, NAMTHANG
# 7   NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM
# 8                     NEW HOPE ACADEMY, SIKIP
# 9                  NEW WISDOM ACADEMY, DENTAM
# ...

# %%
#Multiple Columns
sql="""SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE 'new%' AND `CRCDistance (in KM)` > 5;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-14 16:04:17,673 INFO sqlalchemy.engine.Engine SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND `CRCDistance (in KM)` > 5;
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND `CRCDistance (in KM)` > 5;
# 2022-08-14 16:04:17,684 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                            EstablishmentName
# 0        NEW GARDEN BOARDING SCHOOL (SAJONG)
# 1               NEW VISION ACADEMY, MAJHITAR
# 2          NEW VISION ACADEMY, CHOTA SINGTAM
# 3  NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM
# 4                    NEW HOPE ACADEMY, SIKIP

# %%
sql="""SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%' AND
`CRCDistance (in KM)` > 5;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-14 16:17:03,299 INFO sqlalchemy.engine.Engine SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%' AND
# `CRCDistance (in KM)` > 5;
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE 'new%' AND EstablishmentName LIKE '%academy%' AND
# `CRCDistance (in KM)` > 5;
# 2022-08-14 16:17:03,303 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                            EstablishmentName
# 0               NEW VISION ACADEMY, MAJHITAR
# 1          NEW VISION ACADEMY, CHOTA SINGTAM
# 2  NEW RAYS ACADEMY DEYTHANG BUSTY S. SIKKIM
# 3                    NEW HOPE ACADEMY, SIKIP

# %% [markdown]
# ##ORDER BY and LIMIT

# %%
##to order by a column
#SELECT column
#From table
#ORDER BY column;

# %%
#You can always select more that 1 column to be displayed

#SELECT column1, column2
#FROM table
#ORDER BY column;

# %%
#ORDER BY using DESC


#SELECT column1, column2
#FROM table
#ORDER BY column2 DESC;

# %%
sql="""SELECT EstablishmentName, `CRCDistance (in KM)`, CRCName FROM school_details
ORDER BY `CRCDistance (in KM)` DESC;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-14 16:45:11,140 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, `CRCDistance (in KM)`, CRCName FROM school_details
# ORDER BY `CRCDistance (in KM)` DESC;
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName, `CRCDistance (in KM)`, CRCName FROM school_details
# ORDER BY `CRCDistance (in KM)` DESC;
# 2022-08-14 16:45:11,173 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                  EstablishmentName  CRCDistance (in Km)  \
# 0                      MT. PANDIM ACADEMY, KEWZING                300.0
# 1                 PADMA KUMARI PUBLIC SCHOOL, DUGA                200.0
# 2            PLAY AND LEARN PRIMARY SCHOOL, MANGAN                200.0
# 3                   SARASWATI VIDYALAYA, GYALSHING                120.0
# 4     CHUJACHEN GOVERNMENT SENIOR SECONDARY SCHOOL                 76.0
# ...                                            ...                  ...
# ...

# %%
##ORDER BY with WHERE statement
#SELECT column1, column2
#FROM table
#WHERE column1 LIKE 'a%'
#ORDER BY column2 DESC;

# %%
#LIMIT (similar to .head())
#SELECT * FROM tableLIMIT10;

# %%
sql="""SELECT EstablishmentName, `CRCDistance (in KM)`, CRCName FROM school_details
ORDER BY `CRCDistance (in KM)` DESC
LIMIT 1;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-14 16:46:47,270 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, `CRCDistance (in KM)`, CRCName FROM school_details
# ORDER BY `CRCDistance (in KM)` DESC
# LIMIT 1;
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName, `CRCDistance (in KM)`, CRCName FROM school_details
# ORDER BY `CRCDistance (in KM)` DESC
# LIMIT 1;
# 2022-08-14 16:46:47,285 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#              EstablishmentName  CRCDistance (in Km)  \
# 0  MT. PANDIM ACADEMY, KEWZING                300.0
#
#                                       CRCName
# 0  Kewzing Government Senior Secondary School

# %%
# filter schools that contain 'government' in the establishmentname and order them alphabetically 
#limit the results to 10

sql="""SELECT EstablishmentName
FROM school_details
WHERE EstablishmentName LIKE '%government%'
LIMIT 10;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-14 16:48:53,396 INFO sqlalchemy.engine.Engine SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE '%government%'
# LIMIT 10;
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName
# FROM school_details
# WHERE EstablishmentName LIKE '%government%'
# LIMIT 10;
# 2022-08-14 16:48:53,406 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                    EstablishmentName
# 0               BUDANG GOVERNMENT PRIMARY SCHOOL (E)
# 1  CENTRAL PENDAM GOVERNMENT SENIOR SECONDARY SCHOOL
# 2      CHEURIBOTEY GOVERNMENT JUNIOR HIGH SCHOOL (E)
# 3                   DUGA GOVERNMENT SECONDARY SCHOOL
# 4               KHANI GOAN GOVERNMENT PRIMARY SCHOOL
# 5               OKHARBOTEY GOVERNMENT PRIMARY SCHOOL
# 6                 PACHAK GOVERNMENT SECONDARY SCHOOL
# 7               SAJONG GOVERNMENT JUNIOR HIGH SCHOOL
# 8              SAKHU KHANI GOVERNMENT PRIMARY SCHOOL
# ...

# %%
#select establishment name and crcname and order the schools alphabetically first by the crcname and then by establishment name
#limit 20

sql="""SELECT EstablishmentName, CRCName 
FROM school_details
ORDER BY CRCName, EstablishmentName
LIMIT 20;
"""

pd.read_sql_query(sql, engine)
# Out:
# 2022-08-14 16:52:01,395 INFO sqlalchemy.engine.Engine SELECT EstablishmentName, CRCName
# FROM school_details
# ORDER BY CRCName, EstablishmentName
# LIMIT 20;
# INFO:sqlalchemy.engine.Engine:SELECT EstablishmentName, CRCName
# FROM school_details
# ORDER BY CRCName, EstablishmentName
# LIMIT 20;
# 2022-08-14 16:52:01,404 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                    EstablishmentName  \
# 0             AHO-KISHAN GOVERNMENT SECONDARY SCHOOL
# 1             AHO-SHANTI GOVERNMENT SECONDARY SCHOOL
# 2              AHO-YANGTAM GOVERNMENT PRIMARY SCHOOL
# 3                     BAPTIST ENGLISH SCHOOL, NIMTAR
# 4                BASILAKHA GOVERNMENT PRIMARY SCHOOL
# 5             LITTLE ANGEL ENGLISH SCHOOL, UPPER AHO
# 6              LITTLE ANGEL PRIMARY SCHOOL, KADAMTAM
# 7           LOWER KADAMTAM GOVERNMENT PRIMARY SCHOOL
# 8            NAMCHEYBONG GOVERNMENT SECONDARY SCHOOL
# ...

# %% [markdown]
# ##Aliasing

# %%
#columns
#SELECT column1 AS col1
#FROM table;

# %%
#aggregate
#SELECT MAX(column1) AS Max1
#From table;

# %%
#tables
#SELECT person.name
#FROM person;

# %% [markdown]
# ##Aggregates
# Getting Aggregate Statistics on numerica columns
# AVG:average
#
# SUM: sum of values
#
# MIN: minimum values
#
# MAX: maximum value
#
# COUNT:number of values
#
# DISTINCT: all possible entries for a column

# %%
sql="""SELECT AVG (`CRCDistance (in Km)`)
FROM school_details
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-25 18:24:42,391 INFO sqlalchemy.engine.Engine SELECT AVG (`CRCDistance (in Km)`)
# FROM school_details
# INFO:sqlalchemy.engine.Engine:SELECT AVG (`CRCDistance (in Km)`)
# FROM school_details
# 2022-08-25 18:24:42,397 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#    AVG (`CRCDistance (in Km)`)
# 0                     5.433028

# %%
sql=""" SELECT MAX (`DistrictHQDistance (in Km)`)
FROM school_details;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-25 18:25:35,105 INFO sqlalchemy.engine.Engine  SELECT MAX (`DistrictHQDistance (in Km)`)
# FROM school_details;
# INFO:sqlalchemy.engine.Engine: SELECT MAX (`DistrictHQDistance (in Km)`)
# FROM school_details;
# 2022-08-25 18:25:35,112 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#    MAX (`DistrictHQDistance (in Km)`)
# 0                               170.0

# %%
sql="""SELECT DISTINCT LocatedInRuralOrUrban
FROM school_details;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-25 18:26:20,063 INFO sqlalchemy.engine.Engine SELECT DISTINCT LocatedInRuralOrUrban
# FROM school_details;
# INFO:sqlalchemy.engine.Engine:SELECT DISTINCT LocatedInRuralOrUrban
# FROM school_details;
# 2022-08-25 18:26:20,069 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#   LocatedInRuralOrUrban
# 0            Urban Area
# 1            Rural Area

# %% [markdown]
# ##Aliasing
# used to temporarily rename columns or table.
# Doesn't change it in the original dataset, just used to make identifying columns easier

# %%
#shorten name
#SELECT column1 AS 
#FROM table;

# %%
#rename with an aggregrate
#SELECT MAX(column1) AS Max1
#FROM table;

# %%
#specify tables in columns especially when one column is in multiple tables
#SELECT person.name
#FROM person;


#its common to rename a table with the first letter or two
#SELECT p.name
#FROM person AS p;


#rename the table in the FROM line
#SELECT p.name
#FROM person AS p;

# %% [markdown]
# ##Groupby
# Use with aggregate functions
# Use AS to name results of GROUPBY aggregate functions

# %%
sql="""SELECT LocatedinRuralOrUrban, AVG (`DistrictHQDistance (in Km)`)
FROM school_details
GROUP BY LocatedInRuralOrUrban;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-25 18:36:20,223 INFO sqlalchemy.engine.Engine SELECT LocatedinRuralOrUrban, AVG (`DistrictHQDistance (in Km)`)
# FROM school_details
# GROUP BY LocatedInRuralOrUrban;
# INFO:sqlalchemy.engine.Engine:SELECT LocatedinRuralOrUrban, AVG (`DistrictHQDistance (in Km)`)
# FROM school_details
# GROUP BY LocatedInRuralOrUrban;
# 2022-08-25 18:36:20,229 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#   LocatedInRuralOrUrban  AVG (`DistrictHQDistance (in Km)`)
# 0            Rural Area                            8.336638
# 1            Urban Area                           34.565487

# %%
sql="""SELECT PostOfficeName, MAX(`DistrictHQDistance (in Km)`)
FROM school_details
GROUP BY PostOfficeName;
"""

pd.read_sql_query(sql,engine)
# Out:
# 2022-08-25 18:38:56,390 INFO sqlalchemy.engine.Engine SELECT PostOfficeName, MAX(`DistrictHQDistance (in Km)`)
# FROM school_details
# GROUP BY PostOfficeName;
# INFO:sqlalchemy.engine.Engine:SELECT PostOfficeName, MAX(`DistrictHQDistance (in Km)`)
# FROM school_details
# GROUP BY PostOfficeName;
# 2022-08-25 18:38:56,399 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#     PostOfficeName  MAX(`DistrictHQDistance (in Km)`)
# 0              Aho                               24.0
# 1             Amba                               47.0
# 2           Aritar                               76.0
# 3         Arubotey                               80.0
# 4    Assam Lingzey                               34.0
# ..             ...                                ...
# 173        Yangang                               80.0
# 174        Yangtey                               15.0
# 175      Yangthang                               15.0
# ...

# %%
sql="""SELECT CRCName, COUNT(*)
FROM school_details
GROUP BY CRCName
ORDER BY COUNT(*) DESC;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-25 18:40:07,362 INFO sqlalchemy.engine.Engine SELECT CRCName, COUNT(*)
# FROM school_details
# GROUP BY CRCName
# ORDER BY COUNT(*) DESC;
# INFO:sqlalchemy.engine.Engine:SELECT CRCName, COUNT(*)
# FROM school_details
# GROUP BY CRCName
# ORDER BY COUNT(*) DESC;
# 2022-08-25 18:40:07,365 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                                CRCName  COUNT(*)
# 0                 Chumbong Government Secondary School        44
# 1            Soreng Government Senior Secondary School        42
# 2            Tadong Government Senior Secondary School        33
# 3     Tashi Namgyal Government Senior Secondary School        27
# 4    Biraspati Persai Government Senior Secondary S...        21
# ..                                                 ...       ...
# 121   Saffo Salim Pakyel Government Junior High School         1
# 122                Sakyong Government Secondary School         1
# ...

# %%
sql="""SELECT CRCName, COUNT(*) AS NumberOfSchools
FROM school_details
GROUP BY CRCName
ORDER BY NumberofSchools DESC;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-25 18:42:02,557 INFO sqlalchemy.engine.Engine SELECT CRCName, COUNT(*) AS NumberOfSchools
# FROM school_details
# GROUP BY CRCName
# ORDER BY NumberofSchools DESC;
# INFO:sqlalchemy.engine.Engine:SELECT CRCName, COUNT(*) AS NumberOfSchools
# FROM school_details
# GROUP BY CRCName
# ORDER BY NumberofSchools DESC;
# 2022-08-25 18:42:02,560 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                                CRCName  NumberOfSchools
# 0                 Chumbong Government Secondary School               44
# 1            Soreng Government Senior Secondary School               42
# 2            Tadong Government Senior Secondary School               33
# 3     Tashi Namgyal Government Senior Secondary School               27
# 4    Biraspati Persai Government Senior Secondary S...               21
# ..                                                 ...              ...
# ...

# %% [markdown]
# ##HAVING
# filter values based on the results of aggregate functions with GROUP BY
#
# similar to WHERE but HAVING must be used with GROUPBY

# %%
sql="""SELECT CRCName, COUNT(*)
FROM school_details
GROUP BY CRCName
HAVING COUNT (*)>20;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-25 18:44:25,124 INFO sqlalchemy.engine.Engine SELECT CRCName, COUNT(*)
# FROM school_details
# GROUP BY CRCName
# HAVING COUNT (*)>20;
# INFO:sqlalchemy.engine.Engine:SELECT CRCName, COUNT(*)
# FROM school_details
# GROUP BY CRCName
# HAVING COUNT (*)>20;
# 2022-08-25 18:44:25,134 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                              CRCName  COUNT(*)
# 0  Biraspati Persai Government Senior Secondary S...        21
# 1  Central Pendam Government Senior Secondary School        21
# 2               Chumbong Government Secondary School        44
# 3          Soreng Government Senior Secondary School        42
# 4          Tadong Government Senior Secondary School        33
# 5   Tashi Namgyal Government Senior Secondary School        27

# %%
sql="""SELECT CRCName, COUNT(*) AS NumberofSchools
FROM school_details
GROUP BY CRCName
HAVING NumberofSchools>20;
"""
pd.read_sql_query(sql,engine)
# Out:
# 2022-08-25 18:45:45,924 INFO sqlalchemy.engine.Engine SELECT CRCName, COUNT(*) AS NumberofSchools
# FROM school_details
# GROUP BY CRCName
# HAVING NumberofSchools>20;
# INFO:sqlalchemy.engine.Engine:SELECT CRCName, COUNT(*) AS NumberofSchools
# FROM school_details
# GROUP BY CRCName
# HAVING NumberofSchools>20;
# 2022-08-25 18:45:45,930 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#                                              CRCName  NumberofSchools
# 0  Biraspati Persai Government Senior Secondary S...               21
# 1  Central Pendam Government Senior Secondary School               21
# 2               Chumbong Government Secondary School               44
# 3          Soreng Government Senior Secondary School               42
# 4          Tadong Government Senior Secondary School               33
# 5   Tashi Namgyal Government Senior Secondary School               27

# %%
sql="""SELECT SubdivisionName, AVG(`DISTRICTHQDistance (in Km)`) AS Avg_HQ_Distance
FROM school_details
GROUP BY SubdivisionName
HAVING Avg_HQ_Distance>30;
"""
pd.read_sql_query(sql, engine)
# Out:
# 2022-08-25 18:48:10,046 INFO sqlalchemy.engine.Engine SELECT SubdivisionName, AVG(`DISTRICTHQDistance (in Km)`) AS Avg_HQ_Distance
# FROM school_details
# GROUP BY SubdivisionName
# HAVING Avg_HQ_Distance>30;
# INFO:sqlalchemy.engine.Engine:SELECT SubdivisionName, AVG(`DISTRICTHQDistance (in Km)`) AS Avg_HQ_Distance
# FROM school_details
# GROUP BY SubdivisionName
# HAVING Avg_HQ_Distance>30;
# 2022-08-25 18:48:10,059 INFO sqlalchemy.engine.Engine [raw sql] ()
# INFO:sqlalchemy.engine.Engine:[raw sql] ()
#   SubdivisionName  Avg_HQ_Distance
# 0      Chungthang        39.923077
# 1         Pakyong        37.717949
# 2        Ravangla        40.609023
# 3          Rongli        68.826087
# 4          Soreng        52.417127

# %% [markdown]
# ##Joins
# join multiple tables together
#
#     Inner
#     Left
#     Right
#     Outer or Full

# %%
#SELECT *
#FROM Person p INNER JOIN Location l
  #ON l.id = p.birth_location_id

# %%
#SELECT p.name, l.city
#FROM Person p LEFT JOIN Location l
  #ON l.id = p.birth_location_id

# %%
#SELECT MAX(p.height), l.city
#FROM Person p INNER JOIN Location l
  #ON l.id = p.birth_location_id
#GROUP BY l.city
